# %%
# reding one csv file 
# optional:load data from URL 
#(if connection works) 
import pandas as pd
df_premier21=pd.read_csv("E0.csv")
df_premier21
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00    Liverpool    Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30  Aston Villa      Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00     Brighton         Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00   Sunderland       West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00    Tottenham        Burnley     3     0   H     1
# ..   ..         ...    ...          ...            ...   ...   ...  ..   ...
# 304  E0  21/03/2026  17:30      Everton        Chelsea     3     0   H     1
# 305  E0  21/03/2026  20:00        Leeds      Brentford     0     0   D     0
# 306  E0  22/03/2026  12:00    Newcastle     Sunderland     1     2   A     1
# 307  E0  22/03/2026  14:15  Aston Villa       West Ham     2     0   H     1
# 308  E0  22/03/2026  14:15    Tottenham  Nott'm Forest     0     3   A     0
#
# ...

# %%
# rename some columns
df_premier21.rename(columns={'FTHG':'home_goals',
                             'FTAG':'away_goals'}, inplace=True)

df_premier21
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00    Liverpool    Bournemouth           4
# 1    E0  16/08/2025  12:30  Aston Villa      Newcastle           0
# 2    E0  16/08/2025  15:00     Brighton         Fulham           1
# 3    E0  16/08/2025  15:00   Sunderland       West Ham           3
# 4    E0  16/08/2025  15:00    Tottenham        Burnley           3
# ..   ..         ...    ...          ...            ...         ...
# 304  E0  21/03/2026  17:30      Everton        Chelsea           3
# 305  E0  21/03/2026  20:00        Leeds      Brentford           0
# 306  E0  22/03/2026  12:00    Newcastle     Sunderland           1
# 307  E0  22/03/2026  14:15  Aston Villa       West Ham           2
# 308  E0  22/03/2026  14:15    Tottenham  Nott'm Forest           0
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %%
# loop through range of season
# reading multiple csv files from URLs
# optional:load data from URL 
#(if connection works)
# for season 2024/2025
import pandas as pd

files = [
     "E0.csv",
     "E1.csv",
     "E2.csv",
     "E3.csv"
]

dfs = []

for file in files:
    temp = pd.read_csv(file)
    dfs.append(temp)

df_season1 = pd.concat(dfs, ignore_index=True)

print(df_season1.head())
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHA PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0     0  ...     1.78  2.07   1.85     2.03     1.88     1.94     1.76
# 1     0  ...     1.80  2.02   1.89     2.06     1.80     1.95     1.74
# 2     0  ...     2.03  1.93   2.00     1.84     2.03     1.80     1.96
# 3     0  ...     1.90  1.97   1.95     1.95     1.94     1.86     1.78
# 4     0  ...     1.88  1.99   1.93     1.98     1.91     1.88     1.83
#
#    BFECAHH  BFECAHA  Unnamed: 132
# 0     2.14     1.86           NaN
# ...

# %%
# len frames
len(df_season1)
# Out:
# 1783

# %%
# loop through range of season
# reading multiple csv files from URLs
# optional:load data from URL 
#(if connection works)
# for season 2023/2024
import pandas as pd

files = [
       "E0 (4).csv",
       "E1 (2).csv",
       "E2 (2).csv",
       "E3 (2).csv"
]

dfs = []

for file in files:
    temp = pd.read_csv(file)
    dfs.append(temp)

df_season2 = pd.concat(dfs, ignore_index=True)

print(df_season2.head())
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82     2.05
# 1  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99     1.88
# 2  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99     1.87
# 3  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83     2.04
# 4  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82     2.05
#
#    BFECAHH  BFECAHA
# 0     1.90     2.08
# ...

# %%
# loop through range of season
# reading multiple csv files from URLs
# optional:load data from URL 
#(if connection works)
# for season 2022/2023
import pandas as pd

files = [
       "E0 (5).csv",
       "E1 (3).csv",
       "E2 (4).csv",
       "E3 (3).csv"
]

dfs = []

for file in files:
    temp = pd.read_csv(file)
    dfs.append(temp)

df_season3 = pd.concat(dfs, ignore_index=True)

print(df_season3.head())
# Out:
#   Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  11/08/2023  20:00      Burnley       Man City     0     3   A     0
# 1  E0  12/08/2023  12:30      Arsenal  Nott'm Forest     2     1   H     2
# 2  E0  12/08/2023  15:00  Bournemouth       West Ham     1     1   D     0
# 3  E0  12/08/2023  15:00     Brighton          Luton     4     1   H     1
# 4  E0  12/08/2023  15:00      Everton         Fulham     0     1   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     2  ...     2.28  1.50      1.95      1.98   1.95   1.97      NaN
# 1     0  ...     2.63 -2.00      1.95      1.98   1.93   1.97     2.01
# 2     0  ...     2.12  0.00      2.02      1.91   2.01   1.92     2.06
# 3     0  ...     2.48 -1.75      2.01      1.92   2.00   1.91     2.14
# 4     0  ...     1.71 -0.25      2.06      1.87   2.04   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0      NaN     1.92     1.95
# ...

# %%
# organize all data in dictionary 
#create a dictionary with original name of league as key
dict_countries = {
    "Spanish La Liga"          : 'SP1',
    "Spanish Segunda Division" : 'SP2',
    "German Bundes Liga"       : 'D1',
    "English Premier Liga"     : 'E0',
    "English League 1"         : 'E2',
    "English League 2"         : 'E3'     
}
#get a dictionary element 
dict_countries['Spanish La Liga']
# Out:
# 'SP1'

# %%
# concat all 3 seasons together 
df_all = pd.concat([df_season1, df_season2, df_season3], ignore_index=True, sort=False)
df_all
# Out:
#      Div        Date   Time            HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 0     E0  15/08/2025  20:00           Liverpool  Bournemouth     4     2   H
# 1     E0  16/08/2025  12:30         Aston Villa    Newcastle     0     0   D
# 2     E0  16/08/2025  15:00            Brighton       Fulham     1     1   D
# 3     E0  16/08/2025  15:00          Sunderland     West Ham     3     0   H
# 4     E0  16/08/2025  15:00           Tottenham      Burnley     3     0   H
# ...   ..         ...    ...                 ...          ...   ...   ...  ..
# 5850  E3  27/04/2024  15:00          Gillingham    Doncaster     2     2   D
# 5851  E3  27/04/2024  15:00  Milton Keynes Dons       Sutton     4     4   D
# 5852  E3  27/04/2024  15:00             Salford    Harrogate     2     2   D
# 5853  E3  27/04/2024  15:00             Swindon    Morecambe     3     3   D
# 5854  E3  27/04/2024  15:00             Wrexham    Stockport     2     1   H
#
# ...

# %%
# organize all data in dictionary 
#create a dictionary with original name of league as key
dict_countries = {
    "Spanish La Liga"          : 'SP1',
    "Spanish Segunda Division" : 'SP2',
    "German Bundes Liga"       : 'D1',
    "English Premier Liga"     : 'E0',
    "English League 1"         : 'E2',
    "English League 2"         : 'E3'     
}
df_all = pd.concat([df_season1, df_season2, df_season3], ignore_index=True, sort=False)
df_all

dict_historical_data = {}


leagues = df_all['Div'].unique()


for league in leagues:
    
    dict_historical_data[league] = df_all[df_all['Div'] == league]

dict_historical_data['E0']
# Out:
#      Div        Date   Time          HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 0     E0  15/08/2025  20:00         Liverpool  Bournemouth     4     2   H
# 1     E0  16/08/2025  12:30       Aston Villa    Newcastle     0     0   D
# 2     E0  16/08/2025  15:00          Brighton       Fulham     1     1   D
# 3     E0  16/08/2025  15:00        Sunderland     West Ham     3     0   H
# 4     E0  16/08/2025  15:00         Tottenham      Burnley     3     0   H
# ...   ..         ...    ...               ...          ...   ...   ...  ..
# 4194  E0  19/05/2024  16:00    Crystal Palace  Aston Villa     5     0   H
# 4195  E0  19/05/2024  16:00         Liverpool       Wolves     2     0   H
# 4196  E0  19/05/2024  16:00             Luton       Fulham     2     4   A
# 4197  E0  19/05/2024  16:00          Man City     West Ham     3     1   H
# 4198  E0  19/05/2024  16:00  Sheffield United    Tottenham     0     3   A
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /home/6205c32e-4d00-4e63-bdea-c9ffa8fe7d75
